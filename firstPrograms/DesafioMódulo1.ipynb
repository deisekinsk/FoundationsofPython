# %%
#Código 1
numero_1 = 15
numero_2 = 30
def funcao_1(num1, num2):
    resultado = num1 * num2
    if resultado <= 1000:
        return(resultado)
    else:
        return(num1 + num2)
funcao_1(numero_1,numero_2)
# Out:
# 450

# %%
#Código 2
def funcao_2(num):
    numero_anterior = 0
    for i in list(range (num)):
        resultado = numero_anterior + i
        print ("Número A", i, "Número B", numero_anterior, "Resultado: ", resultado)
        numero_anterior = i
funcao_2(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-f75a7eaf3c25> in <module>
#       6         print ("Número A", i, "Número B", numero_anterior, "Resultado: ", resultado)
#       7         numero_anterior = i
# ----> 8 funcao_2(10,5)
#
# TypeError: funcao_2() takes 1 positional argument but 2 were given

# %%
#Código 3
def funcao_3(str):
    for i in range(1, len(str)-1,2):
        print("Índice[",i,"]", str[i])
funcao_3("ABCD")
# Out:
# Índice[ 1 ] B

# %%
#Código 4
def funcao_4(lista_numerica):
    print("Valor Passado", lista_numerica)
    a = lista_numerica[0]
    b = lista_numerica[-1]
    print(a)
    print(b)
    if (a == b):
        return True
    else:
        return False
    
numeros = [10,20,30,40,10]
numeros2 = [12,3,23,11]
nuemros3 = [10,20,30,40,20,30,10]
funcao_4(numeros)
# Out:
# Valor Passado [10, 20, 30, 40, 10]
# 10
# 10
# True

# %%
#Código 5
class Classe_1:
    def funcao_da_classe_1(self, string):
        dicionario = {'I' : 1, 'V' : 5, 'X' : 10, 'L' : 50, 'C' : 100, 'D' : 500,          'M' : 1000,}
        valor = 0
        for i in range(len(string)):
            if i > 0 and dicionario[string[i]] > dicionario[string[i-1]]:
                valor += dicionario[string[i]] - 2 * dicionario[string[i-1]]
            else:
                valor += dicionario[string[i]]
        return valor
#Instanciando um objeto
intancia = Classe_1()
print(intancia.funcao_da_classe_1('LLXVI'))
# Out:
# 116

# %%
#Código 6
class A:
    def __init__(self):
        self.calcI(30)
        print("i da Classe A", self.i)

    def calcI(self, i):
        self.i = 2 * i;
class B(A):
    def __init__(self):
        super().__init__()

    def calI(self, i):
        self.i = 3 * i;

b = B()
print(b.__init__())
print(b.calcI())
# Out:
# i da Classe A 60
# i da Classe A 60
# None
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-495c5c01643c> in <module>
#      16 b = B()
#      17 print(b.__init__())
# ---> 18 print(b.calcI())
#      19
#
# TypeError: calcI() missing 1 required positional argument: 'i'

# %%
#Código 7
class Classe_2():
    def __init__(self, l, w):
        self.a = l
        self.b = w

    def metodo_1(self):
        return self.a*self.b

objeto_q = Classe_2(12, 10)
print(objeto_q.__init__())
print(objeto_q.metodo_1())
