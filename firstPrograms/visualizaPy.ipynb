# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-2b1baa4d0d00> in <module>
#       1 breakpoint()
# ----> 2 import numpy as np
#       3 from matplotlib import pyplot as plt
#       4
#       5 ys = 200 + np.random.randn(100)
#
# <ipython-input-3-2b1baa4d0d00> in <module>
#       1 breakpoint()
# ----> 2 import numpy as np
#       3 from matplotlib import pyplot as plt
#       4
#       5 ys = 200 + np.random.randn(100)
#
# c:\Users\Deise Kinsk\.vscode\extensions\ms-python.python-2020.11.371526539\pythonFiles\lib\python\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_frame.py in trace_dispatch(self, frame, event, arg)
#    1020                     if is_line:
#    1021                         self.set_suspend(thread, step_cmd, original_step_cmd=info.pydev_original_step_cmd)
# -> 1022                         self.do_wait_suspend(thread, frame, event, arg)
#    1023                     elif is_return:  # return event
#    1024                         back = frame.f_back
#
# c:\Users\Deise Kinsk\.vscode\extensions\ms-python.python-2020.11.371526539\pythonFiles\lib\python\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_frame.py in do_wait_suspend(self, *args, **kwargs)
#     151
#     152     def do_wait_suspend(self, *args, **kwargs):
# --> 153         self._args[0].do_wait_suspend(*args, **kwargs)
#     154
#     155     # IFDEF CYTHON
#
# c:\Users\Deise Kinsk\.vscode\extensions\ms-python.python-2020.11.371526539\pythonFiles\lib\python\debugpy\_vendored\pydevd\pydevd.py in do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    1853
#    1854             with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 1855                 keep_suspended = self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    1856
#    1857         frames_list = None
#
# c:\Users\Deise Kinsk\.vscode\extensions\ms-python.python-2020.11.371526539\pythonFiles\lib\python\debugpy\_vendored\pydevd\pydevd.py in _do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    1888
#    1889             self.process_internal_commands()
# -> 1890             time.sleep(0.01)
#    1891
#    1892         self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#
# KeyboardInterrupt:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400
